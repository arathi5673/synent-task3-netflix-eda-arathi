# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('netflix_titles.csv')
print(df.shape)
df.head()
# Out:
# (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('netflix_titles.csv')
print(df.shape)
df.head()
# Out:
# (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
print("Dataset Shape:", df.shape)
print("\nColumn Names:", df.columns.tolist())
print("\nMissing Values:")
print(df.isnull().sum())
print("\nBasic Statistics:")
df.describe()
# Out:
# Dataset Shape: (8807, 12)
#
# Column Names: ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'release_year', 'rating', 'duration', 'listed_in', 'description']
#
# Missing Values:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
#
# Basic Statistics:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
plt.figure(figsize=(8,5))
df['type'].value_counts().plot(kind='bar', color=['red','blue'])
plt.title('Movies vs TV Shows on Netflix')
plt.xlabel('Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(10,5))
df['country'].value_counts().head(10).plot(kind='bar', color='red')
plt.title('Top 10 Countries with Most Content')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,5))
df['release_year'].value_counts().sort_index().plot(kind='line', color='red')
plt.title('Netflix Content Released Per Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,5))
df['rating'].value_counts().head(10).plot(kind='bar', color='orange')
plt.title('Top Content Ratings on Netflix')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Count movies vs tv shows per year
plt.figure(figsize=(12,5))
df.groupby(['release_year','type']).size().unstack().plot(kind='line')
plt.title('Movies vs TV Shows Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(['Movie','TV Show'])
plt.show()

# Top 10 genres
plt.figure(figsize=(12,5))
df['listed_in'].str.split(',').e
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 12
#       8 plt.show()
#       9
#      10 # Top 10 genres
#      11 plt.figure(figsize=(12,5))
# ---> 12 df['listed_in'].str.split(',').e
#
# File ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'e'

# %%
# Top Ratings
plt.figure(figsize=(10,5))

# Remove missing ratings first
ratings = df['rating'].dropna()

ratings.value_counts().head(10).plot(kind='bar', color='orange')
plt.title('Top Content Ratings on Netflix')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Count movies vs tv shows per year
plt.figure(figsize=(12,5))
df.groupby(['release_year','type']).size().unstack().plot(kind='line')
plt.title('Movies vs TV Shows Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(['Movie','TV Show'])
plt.show()

# Top 10 genres
genres = df['listed_in'].str.split(',').explode().str.strip()
plt.figure(figsize=(12,5))
genres.value_counts().head(10).plot(kind='bar', color='green')
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
print("=== Task 3 - Netflix EDA Complete ===")
print(f"\nTotal Content: {df.shape[0]}")
print(f"Total Columns: {df.shape[1]}")
print(f"\nMovies: {df[df['type']=='Movie'].shape[0]}")
print(f"TV Shows: {df[df['type']=='TV Show'].shape[0]}")
print(f"\nTop Country: {df['country'].value_counts().index[0]}")
print(f"Top Rating: {df['rating'].value_counts().index[0]}")
print(f"Most Content Year: {df['release_year'].value_counts().index[0]}")
print("\nKey Insights:")
print("✅ Movies are more than TV Shows on Netflix")
print("✅ USA produces the most content")
print("✅ TV-MA is the most common rating")
print("✅ Content increased significantly after 2015")print("=== Task 3 - Netflix EDA Complete ===")
print(f"\nTotal Content: {df.shape[0]}")
print(f"Total Columns: {df.shape[1]}")
print(f"\nMovies: {df[df['type']=='Movie'].shape[0]}")
print(f"TV Shows: {df[df['type']=='TV Show'].shape[0]}")
print(f"\nTop Country: {df['country'].value_counts().index[0]}")
print(f"Top Rating: {df['rating'].value_counts().index[0]}")
print(f"Most Content Year: {df['release_year'].value_counts().index[0]}")
print("\nKey Insights:")
print("✅ Movies are more than TV Shows on Netflix")
print("✅ USA produces the most content")
print("✅ TV-MA is the most common rating")
print("✅ Content increased significantly after 2015")
# Out:
#   Cell In[19], line 13
#     print("✅ Content increased significantly after 2015")print("=== Task 3 - Netflix EDA Complete ===")
#                                                          ^
# SyntaxError: invalid syntax

# %%
print("=== Task 3 - Netflix EDA Complete ===")

print(f"\nTotal Content: {df.shape[0]}")
print(f"Total Columns: {df.shape[1]}")

print(f"\nMovies: {df[df['type']=='Movie'].shape[0]}")
print(f"TV Shows: {df[df['type']=='TV Show'].shape[0]}")

print(f"\nTop Country: {df['country'].value_counts().index[0]}")
print(f"Top Rating: {df['rating'].value_counts().index[0]}")
print(f"Most Content Year: {df['release_year'].value_counts().index[0]}")

print("\nKey Insights:")
print("Movies are more than TV Shows on Netflix")
print("USA produces the most content")
print("TV-MA is the most common rating")
print("Content increased significantly after 2015")
# Out:
# === Task 3 - Netflix EDA Complete ===
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 print("=== Task 3 - Netflix EDA Complete ===")
#       2
# ----> 3 print(f"\nTotal Content: {df.shape[0]}")
#       4 print(f"Total Columns: {df.shape[1]}")
#       5
#       6 print(f"\nMovies: {df[df['type']=='Movie'].shape[0]}")
#
# NameError: name 'df' is not defined

# %%
# Movies vs TV Shows trend
plt.figure(figsize=(12,5))
df.groupby(['release_year','type']).size().unstack().plot(kind='line')
plt.title('Movies vs TV Shows Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(['Movie','TV Show'])
plt.tight_layout()
plt.show()

# %%
# Top 10 genres
genres = df['listed_in'].str.split(',').explode().str.strip()
plt.figure(figsize=(12,5))
genres.value_counts().head(10).plot(kind='bar', color='green')
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
